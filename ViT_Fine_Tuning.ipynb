# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorflow_addons
# Out:
# ...
#      |████████████████████████████████| 686kB 4.0MB/s
# ...

# %%
# !pip install tensorflow==2.4.1
# Out:
# ...
#      |████████████████████████████████| 394.3MB 41kB/s
# ...
#      |████████████████████████████████| 3.8MB 33.2MB/s
# ...
#      |████████████████████████████████| 471kB 29.1MB/s
# ...
#      |████████████████████████████████| 2.9MB 34.6MB/s
# ...
#   Found existing installation: grpcio 1.34.1
#     Uninstalling grpcio-1.34.1:
#       Successfully uninstalled grpcio-1.34.1
#   Found existing installation: tensorflow-estimator 2.5.0
#     Uninstalling tensorflow-estimator-2.5.0:
#       Successfully uninstalled tensorflow-estimator-2.5.0
#   Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
#   Found existing installation: gast 0.4.0
#     Uninstalling gast-0.4.0:
#       Successfully uninstalled gast-0.4.0
#   Found existing installation: tensorflow 2.5.0
#     Uninstalling tensorflow-2.5.0:
#       Successfully uninstalled tensorflow-2.5.0
# ...

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import tensorflow_addons as tfa
import glob, warnings
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

warnings.filterwarnings('ignore')
print('TensorFlow Version ' + tf.__version__)
# Out:
# TensorFlow Version 2.4.1

# %%
# !pip install python-resize-image

# %%
# !unzip /content/drive/MyDrive/Final.zip
# Out:
# Archive:  /content/drive/MyDrive/Final.zip
#    creating: Final/
#    creating: Final/Boots/
#   inflating: Final/Boots/Image_1.png
#   inflating: Final/Boots/Image_10.png
#   inflating: Final/Boots/Image_101.png
#   inflating: Final/Boots/Image_102.png
#   inflating: Final/Boots/Image_105.png
#   inflating: Final/Boots/Image_106.png
#   inflating: Final/Boots/Image_108.png
#   inflating: Final/Boots/Image_109.png
#   inflating: Final/Boots/Image_11.png
#   inflating: Final/Boots/Image_110.png
#   inflating: Final/Boots/Image_111.png
#   inflating: Final/Boots/Image_112.png
#   inflating: Final/Boots/Image_118.png
#   inflating: Final/Boots/Image_12.png
#   inflating: Final/Boots/Image_120.png
#   inflating: Final/Boots/Image_121.png
#   inflating: Final/Boots/Image_122.png
#   inflating: Final/Boots/Image_123.png
#   inflating: Final/Boots/Image_124.png
#   inflating: Final/Boots/Image_125.png
#   inflating: Final/Boots/Image_128.png
#   inflating: Final/Boots/Image_129.png
# ...

# %%
import os

# %%
for i,files in enumerate(os.listdir("/content/Final/Boots")):
  os.rename(os.path.join("/content/Final/Boots",files),os.path.join("/content/Final/Boots","{}_Boots.png".format(i)))

for i,files in enumerate(os.listdir("/content/Final/Flip_flops")):
  os.rename(os.path.join("/content/Final/Flip_flops",files),os.path.join("/content/Final/Flip_flops","{}_Flip_flops.png".format(i)))

for i,files in enumerate(os.listdir("/content/Final/Loafers")):
  os.rename(os.path.join("/content/Final/Loafers",files),os.path.join("/content/Final/Loafers","{}_Loafers.png".format(i)))

for i,files in enumerate(os.listdir("/content/Final/Sandals")):
  os.rename(os.path.join("/content/Final/Sandals",files),os.path.join("/content/Final/Sandals","{}_Sandals.png".format(i)))

for i,files in enumerate(os.listdir("/content/Final/Sneakers")):
  os.rename(os.path.join("/content/Final/Sneakers",files),os.path.join("/content/Final/Sneakers","{}_Sneakers.png".format(i)))

for i,files in enumerate(os.listdir("/content/Final/Soccer_Shoes")):
  os.rename(os.path.join("/content/Final/Soccer_Shoes",files),os.path.join("/content/Final/Soccer_Shoes","{}_Soccer_Shoes.png".format(i)))

# %%
# !mkdir Boots

# %%
from PIL import Image

from resizeimage import resizeimage

# %%
NP = []
for files in os.listdir("/content/Final/Boots"):
  with open(os.path.join('/content/Final/Boots',files), 'r+b') as f:
    try:
      with Image.open(f) as image:
        cover = resizeimage.resize_cover(image, [224, 224]) 
        cover.save(os.path.join('/content/Boots',files), image.format)
    except:
      NP.append(files)

# %%
len(NP)
# Out:
# 551

# %%
# !mkdir Flip_flops

# %%
NP2 = []
for files in os.listdir("/content/Final/Flip_flops"):
  with open(os.path.join('/content/Final/Flip_flops',files), 'r+b') as f:
    try:
      with Image.open(f) as image:
        cover = resizeimage.resize_cover(image, [224, 224]) 
        cover.save(os.path.join('/content/Flip_flops',files), image.format)
    except:
      NP2.append(files)

# %%
# !mkdir Loafers

# %%
# !mkdir Sandals

# %%
# !mkdir Sneakers

# %%
# !mkdir Soccer_Shoes

# %%
NP3 = []
for files in os.listdir("/content/Final/Loafers"):
  with open(os.path.join('/content/Final/Loafers',files), 'r+b') as f:
    try:
      with Image.open(f) as image:
        cover = resizeimage.resize_cover(image, [224, 224]) 
        cover.save(os.path.join('/content/Loafers',files), image.format)
    except:
      NP3.append(files)

# %%
NP4 = []
for files in os.listdir("/content/Final/Sandals"):
  with open(os.path.join('/content/Final/Sandals',files), 'r+b') as f:
    try:
      with Image.open(f) as image:
        cover = resizeimage.resize_cover(image, [224, 224]) 
        cover.save(os.path.join('/content/Sandals',files), image.format)
    except:
      NP4.append(files)

# %%
NP5 = []
for files in os.listdir("/content/Final/Sneakers"):
  with open(os.path.join('/content/Final/Sneakers',files), 'r+b') as f:
    try:
      with Image.open(f) as image:
        cover = resizeimage.resize_cover(image, [224, 224]) 
        cover.save(os.path.join('/content/Sneakers',files), image.format)
    except:
      NP5.append(files)

# %%
NP6 = []
for files in os.listdir("/content/Final/Soccer_Shoes"):
  with open(os.path.join('/content/Final/Soccer_Shoes',files), 'r+b') as f:
    try:
      with Image.open(f) as image:
        cover = resizeimage.resize_cover(image, [224, 224]) 
        cover.save(os.path.join('/content/Soccer_Shoes',files), image.format)
    except:
      NP6.append(files)

# %%
# !mkdir no_shoe_found

# %%
NP7 = []
for files in os.listdir("/content/Final/no_shoe_found"):
  with open(os.path.join('/content/Final/no_shoe_found',files), 'r+b') as f:
    try:
      with Image.open(f) as image:
        cover = resizeimage.resize_cover(image, [224, 224]) 
        cover.save(os.path.join('/content/no_shoe_found',files), image.format)
    except:
      NP7.append(files)

# %%
NP7

# %%
Boots = []
label_0 = []
for files in os.listdir("/content/Boots"):
  Boots.append(files)
  label_0.append(0)

# %%
Flip_flops = []
label_1 = []
for files in os.listdir("/content/Flip_flops"):
  Flip_flops.append(files)
  label_1.append(1)

# %%
Loafers = []
label_2 = []
for files in os.listdir("/content/Loafers"):
  Loafers.append(files)
  label_2.append(2)

# %%
Sandals = []
label_3 = []
for files in os.listdir("/content/Sandals"):
  Sandals.append(files)
  label_3.append(3)

# %%
Sneakers = []
label_4 = []
for files in os.listdir("/content/Sneakers"):
  Sneakers.append(files)
  label_4.append(4)

# %%
Soccer_Shoes = []
label_5 = []
for files in os.listdir("/content/Soccer_Shoes"):
  Soccer_Shoes.append(files)
  label_5.append(5)

# %%
no_shoe_found = []
label_6 = []
for files in os.listdir("/content/no_shoe_found"):
  no_shoe_found.append(files)
  label_6.append(6)

# %%
Boots = pd.DataFrame(zip(Boots,label_0),columns = ['image_id','label'])

# %%
Flip_flops = pd.DataFrame(zip(Flip_flops,label_1),columns = ['image_id','label'])

# %%
Loafers = pd.DataFrame(zip(Loafers,label_2),columns = ['image_id','label'])

# %%
Sandals = pd.DataFrame(zip(Sandals,label_3),columns = ['image_id','label'])

# %%
Sneakers = pd.DataFrame(zip(Sneakers,label_4),columns = ['image_id','label'])

# %%
Soccer_Shoes = pd.DataFrame(zip(Soccer_Shoes,label_5),columns = ['image_id','label'])

# %%
no_shoe_found = pd.DataFrame(zip(no_shoe_found,label_6),columns = ['image_id','label'])

# %%
DF_TRAIN = pd.concat([Boots,Flip_flops,Loafers,Sandals,Sneakers,Soccer_Shoes,no_shoe_found],axis=0)

# %%
classes = {0 : "Boots",
           1 : "Flip_flops",
           2 : "Loafers",
           3 : "Sandals",
           4 : "Sneakers",
           5 : "Soccer_Shoes",
           6 : "no_shoe_found"}

# %%
DF_TRAIN = DF_TRAIN.sample(frac=1).reset_index(drop=True)

# %%
DF_TRAIN['label'] = DF_TRAIN['label'].astype(str)

# %%
# !mkdir DATA

# %%
# !cp -r /content/Boots/*.png /content/DATA

# %%
# !cp -r /content/Flip_flops/*.png /content/DATA

# %%
# !cp -r /content/Loafers/*.png /content/DATA

# %%
# !cp -r /content/Sandals/*.png /content/DATA

# %%
# !cp -r /content/Sneakers/*.png /content/DATA

# %%
# !cp -r /content/Soccer_Shoes/*.png /content/DATA

# %%
# !cp -r /content/no_shoe_found/*.png /content/DATA

# %%
TRAIN_PATH = '/content/DATA'

# %%
IMAGE_SIZE = 224
BATCH_SIZE = 16
EPOCHS = 7

# %%
def data_augment(image):
    p_spatial = tf.random.uniform([], 0, 1.0, dtype = tf.float32)
    p_rotate = tf.random.uniform([], 0, 1.0, dtype = tf.float32)
    p_pixel_1 = tf.random.uniform([], 0, 1.0, dtype = tf.float32)
    p_pixel_2 = tf.random.uniform([], 0, 1.0, dtype = tf.float32)
    p_pixel_3 = tf.random.uniform([], 0, 1.0, dtype = tf.float32)
    
    # Flips
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    
    if p_spatial > .75:
        image = tf.image.transpose(image)
        
    # Rotates
    if p_rotate > .75:
        image = tf.image.rot90(image, k = 3) # rotate 270º
    elif p_rotate > .5:
        image = tf.image.rot90(image, k = 2) # rotate 180º
    elif p_rotate > .25:
        image = tf.image.rot90(image, k = 1) # rotate 90º
        
    # Pixel-level transforms
    if p_pixel_1 >= .4:
        image = tf.image.random_saturation(image, lower = .7, upper = 1.3)
    if p_pixel_2 >= .4:
        image = tf.image.random_contrast(image, lower = .8, upper = 1.2)
    if p_pixel_3 >= .4:
        image = tf.image.random_brightness(image, max_delta = .1)
        
    return image

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255,
                                                          samplewise_center = True,
                                                          samplewise_std_normalization = True,
                                                          validation_split = 0.2,
                                                          preprocessing_function = data_augment)

train_gen = datagen.flow_from_dataframe(dataframe = DF_TRAIN,
                                        directory = TRAIN_PATH,
                                        x_col = 'image_id',
                                        y_col = 'label',
                                        subset = 'training',
                                        batch_size = BATCH_SIZE,
                                        seed = 1,
                                        color_mode = 'rgb',
                                        shuffle = True,
                                        class_mode = 'categorical',
                                        target_size = (IMAGE_SIZE, IMAGE_SIZE))

valid_gen = datagen.flow_from_dataframe(dataframe = DF_TRAIN,
                                        directory = TRAIN_PATH,
                                        x_col = 'image_id',
                                        y_col = 'label',
                                        subset = 'validation',
                                        batch_size = BATCH_SIZE,
                                        seed = 1,
                                        color_mode = 'rgb',
                                        shuffle = False,
                                        class_mode = 'categorical',
                                        target_size = (IMAGE_SIZE, IMAGE_SIZE))
# Out:
# Found 2481 validated image filenames belonging to 7 classes.
# Found 620 validated image filenames belonging to 7 classes.

# %%
vit_model = vit.vit_b32(
        image_size = IMAGE_SIZE,
        activation = 'softmax',
        pretrained = True,
        include_top = False,
        pretrained_top = False,
        classes = 6)
# Out:
# ...
# 353255424/353253686 [==============================] - 4s 0us/step

# %%
model = tf.keras.Sequential([
        vit_model,
        tf.keras.layers.Flatten(),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dense(11, activation = tfa.activations.gelu),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dense(7, 'softmax')
    ],
    name = 'vision_transformer')

model.summary()
# Out:
# Model: "vision_transformer"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# vit-b32 (Functional)         (None, 768)               87455232
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 768)               0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 768)               3072
# _________________________________________________________________
# dense_4 (Dense)              (None, 11)                8459
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 11)                44
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 84
# ...
# Total params: 87,466,891
# Trainable params: 87,465,333
# Non-trainable params: 1,558
# ...

# %%
learning_rate = 1e-4

optimizer = tfa.optimizers.RectifiedAdam(learning_rate = learning_rate)

model.compile(optimizer = optimizer, 
              loss = tf.keras.losses.CategoricalCrossentropy(label_smoothing = 0.2), 
              metrics = ['accuracy'])

STEP_SIZE_TRAIN = train_gen.n // train_gen.batch_size
STEP_SIZE_VALID = valid_gen.n // valid_gen.batch_size

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor = 'val_accuracy',
                                                 factor = 0.2,
                                                 patience = 2,
                                                 verbose = 1,
                                                 min_delta = 1e-4,
                                                 min_lr = 1e-6,
                                                 mode = 'max')

earlystopping = tf.keras.callbacks.EarlyStopping(monitor = 'val_accuracy',
                                                 min_delta = 1e-4,
                                                 patience = 5,
                                                 mode = 'max',
                                                 restore_best_weights = True,
                                                 verbose = 1)

checkpointer = tf.keras.callbacks.ModelCheckpoint(filepath = './model.hdf5',
                                                  monitor = 'val_accuracy', 
                                                  verbose = 1, 
                                                  save_best_only = True,
                                                  save_weights_only = True,
                                                  mode = 'max')

callbacks = [earlystopping, reduce_lr, checkpointer]

model.fit(x = train_gen,
          steps_per_epoch = STEP_SIZE_TRAIN,
          validation_data = valid_gen,
          validation_steps = STEP_SIZE_VALID,
          epochs = 10,
          callbacks = callbacks)
# Out:
# Epoch 1/10
# 155/155 [==============================] - 114s 392ms/step - loss: 2.3663 - accuracy: 0.2224 - val_loss: 1.5795 - val_accuracy: 0.5592
#
# Epoch 00001: val_accuracy improved from -inf to 0.55921, saving model to ./model.hdf5
# Epoch 2/10
# 155/155 [==============================] - 59s 377ms/step - loss: 1.5171 - accuracy: 0.5831 - val_loss: 1.2639 - val_accuracy: 0.7911
#
# Epoch 00002: val_accuracy improved from 0.55921 to 0.79112, saving model to ./model.hdf5
# Epoch 3/10
# 155/155 [==============================] - 58s 374ms/step - loss: 1.2930 - accuracy: 0.7374 - val_loss: 1.1882 - val_accuracy: 0.8224
#
# Epoch 00003: val_accuracy improved from 0.79112 to 0.82237, saving model to ./model.hdf5
# Epoch 4/10
# 155/155 [==============================] - 58s 373ms/step - loss: 1.1575 - accuracy: 0.8240 - val_loss: 1.1681 - val_accuracy: 0.8520
#
# Epoch 00004: val_accuracy improved from 0.82237 to 0.85197, saving model to ./model.hdf5
# Epoch 5/10
# ...

# %%
model.save('/content/saved')
# Out:
# WARNING:absl:Found untraced functions such as MultiHeadDotProductAttention_1_layer_call_and_return_conditional_losses, MultiHeadDotProductAttention_1_layer_call_fn, LayerNorm_0_layer_call_and_return_conditional_losses, LayerNorm_0_layer_call_fn, LayerNorm_2_layer_call_and_return_conditional_losses while saving (showing 5 of 480). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as MultiHeadDotProductAttention_1_layer_call_and_return_conditional_losses, MultiHeadDotProductAttention_1_layer_call_fn, LayerNorm_0_layer_call_and_return_conditional_losses, LayerNorm_0_layer_call_fn, LayerNorm_2_layer_call_and_return_conditional_losses while saving (showing 5 of 480). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/saved/assets
# INFO:tensorflow:Assets written to: /content/saved/assets

# %%
from tensorflow import keras
modell = keras.models.load_model('/content/saved')

# %%
predicted_classes = np.argmax(modell.predict(valid_gen, steps = valid_gen.n // valid_gen.batch_size + 1), axis = 1)
true_classes = valid_gen.classes
class_labels = list(valid_gen.class_indices.keys())  

confusionmatrix = confusion_matrix(true_classes, predicted_classes)
plt.figure(figsize = (16, 16))
sns.heatmap(confusionmatrix, cmap = 'Blues', annot = True, cbar = True)

print(classification_report(true_classes, predicted_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91       112
#            1       0.92      0.89      0.91        92
#            2       0.89      0.93      0.91       109
#            3       0.92      0.82      0.87        80
#            4       0.84      0.81      0.82        69
#            5       0.85      0.93      0.89        97
#            6       0.98      1.00      0.99        61
#
#     accuracy                           0.90       620
#    macro avg       0.90      0.90      0.90       620
# weighted avg       0.90      0.90      0.90       620
